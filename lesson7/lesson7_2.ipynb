# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
import chromadb

# current_dir = os.getcwd()
current_dir = os.path.dirname(os.path.abspath("__file__"))
file_path = os.path.join(current_dir, "books", "智慧型手機使用手冊.txt")
persistent_directory = os.path.join(current_dir, "db", "chroma_db_v3")

try:
    if not os.path.exists(persistent_directory):
        if not os.path.exists(file_path):
            raise FileNotFoundError(
                f"檔案{file_path}不存在,請檢查路徑!"
            )
        # print("檔案正確")
        loader = TextLoader(file_path=file_path, encoding="utf-8")
        documents = loader.load()
        text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=200)
        docs = text_splitter.split_documents(documents)
        embeddings = HuggingFaceEmbeddings(
            model_name="BAAI/bge-m3"
        )

        client = chromadb.PersistentClient(path=persistent_directory)
        Chroma.from_documents(
            docs,
            embedding=embeddings,
            client = client,
            collection_name="smartphone_manual"
        )
    else:
        print("向量資料庫已經存在，不需要初始化!")
except Exception as error:
    print(error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from langchain_community.document_loaders import TextLoader
#       3 from langchain_text_splitters import CharacterTextSplitter
#       4 from langchain_huggingface import HuggingFaceEmbeddings
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_community\document_loaders\__init__.py:740, in __getattr__(name)
#     738 def __getattr__(name: str) -> Any:
#     739     if name in _module_lookup:
# --> 740         module = importlib.import_module(_module_lookup[name])
#     741         return getattr(module, name)
#     742     raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_community\document_loaders\text.py:7
#       3 from typing import Iterator, Optional, Union
#       5 from langchain_core.documents import Document
# ----> 7 from langchain_community.document_loaders.base import BaseLoader
#       8 from langchain_community.document_loaders.helpers import detect_file_encodings
#      10 logger = logging.getLogger(__name__)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_community\document_loaders\base.py:1
# ----> 1 from langchain_core.document_loaders import BaseBlobParser, BaseLoader
#       3 __all__ = [
#       4     "BaseBlobParser",
#       5     "BaseLoader",
#       6 ]
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_core\document_loaders\__init__.py:33, in __getattr__(attr_name)
#      31 def __getattr__(attr_name: str) -> object:
#      32     module_name = _dynamic_imports.get(attr_name)
# ---> 33     result = import_attr(attr_name, module_name, __spec__.parent)
#      34     globals()[attr_name] = result
#      35     return result
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_core\document_loaders\base.py:19
#      16     from langchain_core.documents.base import Blob
#      18 try:
# ---> 19     from langchain_text_splitters import RecursiveCharacterTextSplitter
#      21     _HAS_TEXT_SPLITTERS = True
#      22 except ImportError:
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_text_splitters\__init__.py:8
#       1 """**Text Splitters** are classes for splitting text.
#       2
#       3 !!! note
#       4     **MarkdownHeaderTextSplitter** and **HTMLHeaderTextSplitter do not derive from
#       5     TextSplitter.
#       6 """
# ----> 8 from langchain_text_splitters.base import (
#       9     Language,
#      10     TextSplitter,
#      11     Tokenizer,
#      12     TokenTextSplitter,
#      13     split_text_on_tokens,
#      14 )
#      15 from langchain_text_splitters.character import (
#      16     CharacterTextSplitter,
#      17     RecursiveCharacterTextSplitter,
#      18 )
#      19 from langchain_text_splitters.html import (
#      20     ElementType,
#      21     HTMLHeaderTextSplitter,
#      22     HTMLSectionSplitter,
#      23     HTMLSemanticPreservingSplitter,
#      24 )
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\langchain_text_splitters\base.py:33
#      30     _HAS_TIKTOKEN = False
#      32 try:
# ---> 33     from transformers.tokenization_utils_base import PreTrainedTokenizerBase
#      35     _HAS_TRANSFORMERS = True
#      36 except ImportError:
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\utils\generic.py:34
#      31 import numpy as np
#      33 from ..utils import logging
# ---> 34 from .import_utils import (
#      35     is_flax_available,
#      36     is_mlx_available,
#      37     is_tf_available,
#      38     is_torch_available,
#      39     is_torch_fx_proxy,
#      40     requires,
#      41 )
#      44 _CAN_RECORD_REGISTRY = {}
#      47 logger = logging.get_logger(__name__)
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\utils\import_utils.py:200
#     198 _phonemizer_available = _is_package_available("phonemizer")
#     199 _uroman_available = _is_package_available("uroman")
# --> 200 _psutil_available = _is_package_available("psutil")
#     201 _py3nvml_available = _is_package_available("py3nvml")
#     202 _pyctcdecode_available = _is_package_available("pyctcdecode")
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\transformers\utils\import_utils.py:57, in _is_package_available(pkg_name, return_version)
#      49 if package_exists:
#      50     try:
#      51         # TODO: Once python 3.9 support is dropped, `importlib.metadata.packages_distributions()`
#      52         # should be used here to map from package name to distribution names
#    (...)
#      55
#      56         # Primary method to get the package version
# ---> 57         package_version = importlib.metadata.version(pkg_name)
#      58     except importlib.metadata.PackageNotFoundError:
#      59         # Fallback method: Only for "torch" and versions containing "dev"
#      60         if pkg_name == "torch":
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\importlib\metadata\__init__.py:996, in version(distribution_name)
#     989 def version(distribution_name):
#     990     """Get the version string for the named package.
#     991
#     992     :param distribution_name: The name of the distribution package to query.
#     993     :return: The version string for the package as defined in the package's
#     994         "Version" metadata key.
#     995     """
# --> 996     return distribution(distribution_name).version
#
# File d:\GitHub\Lang_Chain\.venv\lib\site-packages\importlib_metadata\__init__.py:557, in Distribution.version(self)
#     554 @property
#     555 def version(self) -> str:
#     556     """Return the 'Version' metadata for the distribution package."""
# --> 557     return md_none(self.metadata)['Version']
#
# TypeError: 'NoneType' object is not subscriptable
